# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import mplcyberpunk

# %% [markdown]
# # Data Loading

# %%
matches = pd.read_csv("matches.csv", index_col=0)

# %%
matches.head()
# Out:
#          date   time            comp        round  day venue result   gf   ga  \
# 1  2021-08-15  16:30  Premier League  Matchweek 1  Sun  Away      L  0.0  1.0
# 2  2021-08-21  15:00  Premier League  Matchweek 2  Sat  Home      W  5.0  0.0
# 3  2021-08-28  12:30  Premier League  Matchweek 3  Sat  Home      W  5.0  0.0
# 4  2021-09-11  15:00  Premier League  Matchweek 4  Sat  Away      W  1.0  0.0
# 6  2021-09-18  15:00  Premier League  Matchweek 5  Sat  Home      D  0.0  0.0
#
#          opponent  ...  match report  notes    sh   sot  dist   fk   pk pkatt  \
# 1       Tottenham  ...  Match Report    NaN  18.0   4.0  16.9  1.0  0.0   0.0
# 2    Norwich City  ...  Match Report    NaN  16.0   4.0  17.3  1.0  0.0   0.0
# 3         Arsenal  ...  Match Report    NaN  25.0  10.0  14.3  0.0  0.0   0.0
# 4  Leicester City  ...  Match Report    NaN  25.0   8.0  14.0  0.0  0.0   0.0
# 6     Southampton  ...  Match Report    NaN  16.0   1.0  15.7  1.0  0.0   0.0
#
#    season             team
# ...

# %% [markdown]
# # EDA

# %%
matches.shape
# Out:
# (1389, 27)

# %%
# 2 seasons * 20 squads * 38 matches

2 * 20 * 38
# Out:
# 1520

# %%
# Missing Liverpool 2021-2022
matches["team"].value_counts()
# Out:
# team
# Southampton                 72
# Brighton and Hove Albion    72
# Manchester United           72
# West Ham United             72
# Newcastle United            72
# Burnley                     71
# Leeds United                71
# Crystal Palace              71
# Manchester City             71
# Wolverhampton Wanderers     71
# Tottenham Hotspur           71
# Arsenal                     71
# Leicester City              70
# Chelsea                     70
# Aston Villa                 70
# Everton                     70
# Liverpool                   38
# Fulham                      38
# West Bromwich Albion        38
# Sheffield United            38
# Brentford                   34
# Watford                     33
# Norwich City                33
# Name: count, dtype: int64

# %%
matches[matches["team"] == "Liverpool"].sort_values("date")
# Out:
#           date   time            comp         round  day venue result   gf  \
# 1   2020-09-12  17:30  Premier League   Matchweek 1  Sat  Home      W  4.0
# 2   2020-09-20  16:30  Premier League   Matchweek 2  Sun  Away      W  2.0
# 4   2020-09-28  20:00  Premier League   Matchweek 3  Mon  Home      W  3.0
# 6   2020-10-04  19:15  Premier League   Matchweek 4  Sun  Away      L  2.0
# 7   2020-10-17  12:30  Premier League   Matchweek 5  Sat  Away      D  2.0
# 9   2020-10-24  20:00  Premier League   Matchweek 6  Sat  Home      W  2.0
# 11  2020-10-31  17:30  Premier League   Matchweek 7  Sat  Home      W  2.0
# 13  2020-11-08  16:30  Premier League   Matchweek 8  Sun  Away      D  1.0
# 14  2020-11-22  19:15  Premier League   Matchweek 9  Sun  Home      W  3.0
# 16  2020-11-28  12:30  Premier League  Matchweek 10  Sat  Away      D  1.0
# 18  2020-12-06  19:15  Premier League  Matchweek 11  Sun  Home      W  4.0
# ...

# %%
matches["round"].value_counts()
# Out:
# round
# Matchweek 1     39
# Matchweek 16    39
# Matchweek 34    39
# Matchweek 32    39
# Matchweek 31    39
# Matchweek 29    39
# Matchweek 28    39
# Matchweek 26    39
# Matchweek 25    39
# Matchweek 24    39
# Matchweek 23    39
# Matchweek 2     39
# Matchweek 19    39
# Matchweek 17    39
# Matchweek 20    39
# Matchweek 15    39
# Matchweek 5     39
# Matchweek 3     39
# Matchweek 13    39
# Matchweek 12    39
# Matchweek 4     39
# Matchweek 11    39
# Matchweek 10    39
# Matchweek 9     39
# Matchweek 8     39
# Matchweek 14    39
# Matchweek 7     39
# Matchweek 6     39
# Matchweek 30    37
# Matchweek 27    37
# Matchweek 22    37
# Matchweek 21    37
# Matchweek 18    37
# Matchweek 33    32
# Matchweek 35    20
# Matchweek 36    20
# Matchweek 37    20
# Matchweek 38    20
# Name: count, dtype: int64

# %%
matches.dtypes
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf              float64
# ga              float64
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes           float64
# sh              float64
# sot             float64
# dist            float64
# fk              float64
# pk              float64
# pkatt           float64
# season            int64
# team             object
# dtype: object

# %%
# Summary statistics for numerical columns
numerical_summary = matches.describe()
numerical_summary
# Out:
#                 gf           ga           xg          xga         poss  \
# count  1389.000000  1389.000000  1389.000000  1389.000000  1389.000000
# mean      1.335493     1.380850     1.304176     1.338445    49.702664
# std       1.274235     1.291049     0.767268     0.789360    12.401897
# min       0.000000     0.000000     0.000000     0.000000    18.000000
# 25%       0.000000     0.000000     0.700000     0.700000    40.000000
# 50%       1.000000     1.000000     1.200000     1.200000    50.000000
# 75%       2.000000     2.000000     1.800000     1.800000    59.000000
# max       9.000000     9.000000     4.600000     5.000000    82.000000
#
#          attendance  notes           sh          sot         dist  \
# count    693.000000    0.0  1389.000000  1389.000000  1388.000000
# mean   36089.963925    NaN    12.153348     4.041037    17.011527
# std    17797.991778    NaN     5.268876     2.403866     2.988364
# ...

# %%
# Summary statistics for categorical columns
categorical_summary = matches.describe(include=['object'])
categorical_summary
# Out:
#               date   time            comp        round   day venue result  \
# count         1389   1389            1389         1389  1389  1389   1389
# unique         244     18               1           38     7     2      3
# top     2021-05-23  15:00  Premier League  Matchweek 1   Sat  Away      L
# freq            20    286            1389           39   551   695    548
#
#            opponent      captain formation         referee  match report  \
# count          1389         1389      1389            1389          1389
# unique           23           91        16              23             1
# top     Southampton  Hugo Lloris   4-2-3-1  Anthony Taylor  Match Report
# freq             71           70       344             100          1389
#
#                team
# count          1389
# unique           23
# top     Southampton
# freq             72

# %%
# Step 1: Group by Team and Sum Goals
team_goals = matches.groupby('team')['gf'].sum().reset_index()

# Step 2: Sort and Select Top 10 Teams
top_10_teams = team_goals.sort_values(by='gf', ascending=False).head(10)

plt.style.use('cyberpunk')
plt.figure(figsize=(12, 5))
sns.barplot(x='gf', y='team', data=top_10_teams, palette='viridis',hue='team',legend=False)
plt.title('Top 10 Teams with Most Goals')
plt.xlabel('Total Goals')
plt.ylabel('Team')
mplcyberpunk.add_glow_effects()
plt.show()

# %%
# Step 1: Filter Wins
# Assuming 'result' column contains 'win' for wins
wins = matches[matches['result'] == 'W']

# Step 2: Group by Team and Count Wins
team_wins = wins.groupby('team')['result'].count().reset_index()
team_wins.columns = ['team', 'wins']

# Step 3: Sort and Select Top 10 Teams
top_10_teams_wins = team_wins.sort_values(by='wins', ascending=False).head(10)


# Step 4: Visualize the Results
plt.style.use('cyberpunk')
plt.figure(figsize=(12, 5))
sns.barplot(x='wins', y='team', data=top_10_teams_wins, palette='viridis',hue='team')
plt.title('Top 10 Teams with Most Wins')
plt.xlabel('Total Wins')
plt.ylabel('Team')
mplcyberpunk.add_glow_effects()
plt.show()

# %%
top_10_attended_matches = matches.sort_values(by='attendance', ascending=False).head(10)


# Create a new column to uniquely identify each match by concatenating team and date
top_10_attended_matches['team_opponent'] = top_10_attended_matches['team'] + ' vs ' + top_10_attended_matches['opponent']

# Step 4: Visualize the Results
plt.figure(figsize=(12, 6))
sns.barplot(x='attendance', y='team_opponent', data=top_10_attended_matches, palette='viridis',hue='team_opponent')
plt.title('Top 10 Most Attended Matches')
plt.xlabel('Attendance')
plt.ylabel('Match')
mplcyberpunk.add_glow_effects()
plt.show()

# %%
wins = matches[matches['result'] == 'W']

# Step 2: Group by Formation and Count Wins
formation_wins = wins.groupby('formation')['result'].count().reset_index()
formation_wins.columns = ['formation', 'wins']

# Step 3: Sort and Select Top 5 Formations
top_5_formations = formation_wins.sort_values(by='wins', ascending=False).head(5)

# Display the top 5 formations with most wins
print(top_5_formations)

# Step 4: Visualize the Results
plt.figure(figsize=(10, 3))
sns.barplot(x='wins', y='formation', data=top_5_formations, palette='viridis',hue='formation')
plt.title('Top 5 Most Effective Formations')
plt.xlabel('Number of Wins')
plt.ylabel('Formation')
mplcyberpunk.add_glow_effects()
plt.show()
# Out:
#    formation  wins
# 6    4-2-3-1   153
# 7      4-3-3   118
# 1      3-4-3    82
# 10     4-4-2    60
# 3      3-5-2    39

# %%
wins_by_venue = matches[matches['result'] == 'W'].groupby('venue').size().reset_index(name='wins')
plt.figure(figsize=(8, 3))
sns.barplot(x='wins', y='venue', data=wins_by_venue, palette='viridis',hue='venue')
plt.title('Wins by Venue')
plt.xlabel('Number of Wins')
plt.ylabel('Venue')
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.kdeplot(x='sh', y='sot', data=matches, fill=True, cmap='viridis', thresh=0.05)
plt.title('Density Plot of Shots vs. Shots on Target')
plt.xlabel('Shots')
plt.ylabel('Shots on Target')
plt.text(1, 12, 'High-Density Region\n- Most matches\n- Shots: 8-12\n- Shots on Target: 3-5',
         color='white', fontsize=10, bbox=dict(facecolor='black', alpha=0.5))
plt.text(20, 1, 'Low-Density Region\n- Few matches\n- Extreme values',
         color='white', fontsize=10, bbox=dict(facecolor='black', alpha=0.5))
plt.text(15, 12, 'General Trend:\nMore shots lead\nto more shots on target',
         color='white', fontsize=10, bbox=dict(facecolor='black', alpha=0.5))
plt.show()

# %% [markdown]
# # Preprocessing

# %%
del matches["comp"]

# %%
del matches["notes"]

# %%
matches["date"] = pd.to_datetime(matches["date"])

# %%
matches["target"] = (matches["result"] == "W").astype("int")

# %%
matches
# Out:
#          date   time         round  day venue result   gf   ga  \
# 1  2021-08-15  16:30   Matchweek 1  Sun  Away      L  0.0  1.0
# 2  2021-08-21  15:00   Matchweek 2  Sat  Home      W  5.0  0.0
# 3  2021-08-28  12:30   Matchweek 3  Sat  Home      W  5.0  0.0
# 4  2021-09-11  15:00   Matchweek 4  Sat  Away      W  1.0  0.0
# 6  2021-09-18  15:00   Matchweek 5  Sat  Home      D  0.0  0.0
# ..        ...    ...           ...  ...   ...    ...  ...  ...
# 38 2021-05-02  19:15  Matchweek 34  Sun  Away      L  0.0  4.0
# 39 2021-05-08  15:00  Matchweek 35  Sat  Home      L  0.0  2.0
# 40 2021-05-16  19:00  Matchweek 36  Sun  Away      W  1.0  0.0
# 41 2021-05-19  18:00  Matchweek 37  Wed  Away      L  0.0  1.0
# 42 2021-05-23  16:00  Matchweek 38  Sun  Home      W  1.0  0.0
#
#           opponent   xg  ...  match report    sh   sot  dist   fk   pk pkatt  \
# 1        Tottenham  1.9  ...  Match Report  18.0   4.0  16.9  1.0  0.0   0.0
# ...

# %%
matches["venue_code"] = matches["venue"].astype("category").cat.codes

# %%
matches["opp_code"] = matches["opponent"].astype("category").cat.codes

# %%
matches["hour"] = matches["time"].str.replace(":.+", "", regex=True).astype("int")

# %%
matches["day_code"] = matches["date"].dt.dayofweek

# %%
matches
# Out:
#          date   time         round  day venue result   gf   ga  \
# 1  2021-08-15  16:30   Matchweek 1  Sun  Away      L  0.0  1.0
# 2  2021-08-21  15:00   Matchweek 2  Sat  Home      W  5.0  0.0
# 3  2021-08-28  12:30   Matchweek 3  Sat  Home      W  5.0  0.0
# 4  2021-09-11  15:00   Matchweek 4  Sat  Away      W  1.0  0.0
# 6  2021-09-18  15:00   Matchweek 5  Sat  Home      D  0.0  0.0
# ..        ...    ...           ...  ...   ...    ...  ...  ...
# 38 2021-05-02  19:15  Matchweek 34  Sun  Away      L  0.0  4.0
# 39 2021-05-08  15:00  Matchweek 35  Sat  Home      L  0.0  2.0
# 40 2021-05-16  19:00  Matchweek 36  Sun  Away      W  1.0  0.0
# 41 2021-05-19  18:00  Matchweek 37  Wed  Away      L  0.0  1.0
# 42 2021-05-23  16:00  Matchweek 38  Sun  Home      W  1.0  0.0
#
#           opponent   xg  ...   fk   pk  pkatt season              team target  \
# 1        Tottenham  1.9  ...  1.0  0.0    0.0   2022   Manchester City      0
# ...

# %% [markdown]
# # Machine Learning

# %% [markdown]
# ### Applying Model

# %% [markdown]
# Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
train = matches[matches["date"] < '2022-01-01']

# %%
test = matches[matches["date"] > '2022-01-01']

# %%
predictors = ["venue_code", "opp_code", "hour", "day_code"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %% [markdown]
# ### Evaluation

# %%
from sklearn.metrics import accuracy_score

# %%
error = accuracy_score(test["target"], preds)

# %%
error
# Out:
# 0.6123188405797102

# %%
combined = pd.DataFrame(dict(actual=test["target"], predicted=preds))

# %%
pd.crosstab(index=combined["actual"], columns=combined["predicted"])
# Out:
# predicted    0   1
# actual
# 0          141  31
# 1           76  28

# %%
from sklearn.metrics import precision_score

precision_score(test["target"], preds)
# Out:
# 0.4745762711864407

# %% [markdown]
# ### Improving Accuracy and Precision

# %%
grouped_matches = matches.groupby("team")

# %%
group = grouped_matches.get_group("Manchester City").sort_values("date")

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]

rolling_averages(group, cols, new_cols)
# Out:
#          date   time         round  day venue result   gf   ga  \
# 5  2020-10-17  17:30   Matchweek 5  Sat  Home      W  1.0  0.0
# 7  2020-10-24  12:30   Matchweek 6  Sat  Away      D  1.0  1.0
# 9  2020-10-31  12:30   Matchweek 7  Sat  Away      W  1.0  0.0
# 11 2020-11-08  16:30   Matchweek 8  Sun  Home      D  1.0  1.0
# 12 2020-11-21  17:30   Matchweek 9  Sat  Away      L  0.0  2.0
# ..        ...    ...           ...  ...   ...    ...  ...  ...
# 42 2022-03-14  20:00  Matchweek 29  Mon  Away      D  0.0  0.0
# 44 2022-04-02  15:00  Matchweek 31  Sat  Away      W  2.0  0.0
# 46 2022-04-10  16:30  Matchweek 32  Sun  Home      D  2.0  2.0
# 49 2022-04-20  20:00  Matchweek 30  Wed  Home      W  3.0  0.0
# 50 2022-04-23  15:00  Matchweek 34  Sat  Home      W  5.0  1.0
#
#           opponent   xg  ...  hour  day_code  gf_rolling ga_rolling  \
# 5          Arsenal  1.5  ...    17         5    2.000000   2.333333
# 7         West Ham  1.1  ...    12         5    1.333333   2.000000
# ...

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
matches_rolling
# Out:
#                                  date   time         round  day venue result  \
# team
# Arsenal                 6  2020-10-04  14:00   Matchweek 4  Sun  Home      W
#                         7  2020-10-17  17:30   Matchweek 5  Sat  Away      L
#                         9  2020-10-25  19:15   Matchweek 6  Sun  Home      L
#                         11 2020-11-01  16:30   Matchweek 7  Sun  Away      W
#                         13 2020-11-08  19:15   Matchweek 8  Sun  Home      L
# ...                               ...    ...           ...  ...   ...    ...
# Wolverhampton Wanderers 32 2022-03-13  14:00  Matchweek 29  Sun  Away      W
#                         33 2022-03-18  20:00  Matchweek 30  Fri  Home      L
#                         34 2022-04-02  15:00  Matchweek 31  Sat  Home      W
#                         35 2022-04-08  20:00  Matchweek 32  Fri  Away      L
#                         36 2022-04-24  14:00  Matchweek 34  Sun  Away      L
#
# ...

# %%
matches_rolling = matches_rolling.droplevel('team')

# %%
matches_rolling
# Out:
#          date   time         round  day venue result   gf   ga  \
# 6  2020-10-04  14:00   Matchweek 4  Sun  Home      W  2.0  1.0
# 7  2020-10-17  17:30   Matchweek 5  Sat  Away      L  0.0  1.0
# 9  2020-10-25  19:15   Matchweek 6  Sun  Home      L  0.0  1.0
# 11 2020-11-01  16:30   Matchweek 7  Sun  Away      W  1.0  0.0
# 13 2020-11-08  19:15   Matchweek 8  Sun  Home      L  0.0  3.0
# ..        ...    ...           ...  ...   ...    ...  ...  ...
# 32 2022-03-13  14:00  Matchweek 29  Sun  Away      W  1.0  0.0
# 33 2022-03-18  20:00  Matchweek 30  Fri  Home      L  2.0  3.0
# 34 2022-04-02  15:00  Matchweek 31  Sat  Home      W  2.0  1.0
# 35 2022-04-08  20:00  Matchweek 32  Fri  Away      L  0.0  1.0
# 36 2022-04-24  14:00  Matchweek 34  Sun  Away      L  0.0  1.0
#
#            opponent   xg  ...  hour  day_code  gf_rolling ga_rolling  \
# 6     Sheffield Utd  0.4  ...    14         6    2.000000   1.333333
# ...

# %%
matches_rolling.index = range(matches_rolling.shape[0])

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < '2022-01-01']
    test = data[data["date"] > '2022-01-01']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)
    error = precision_score(test["target"], preds)
    return combined, error

# %%
combined, error = make_predictions(matches_rolling, predictors + new_cols)

# %%
error
# Out:
# 0.625

# %%
combined = combined.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)

# %%
combined.head(10)
# Out:
#     actual  predicted       date     team        opponent result
# 55       0          0 2022-01-23  Arsenal         Burnley      D
# 56       1          0 2022-02-10  Arsenal          Wolves      W
# 57       1          0 2022-02-19  Arsenal       Brentford      W
# 58       1          1 2022-02-24  Arsenal          Wolves      W
# 59       1          1 2022-03-06  Arsenal         Watford      W
# 60       1          1 2022-03-13  Arsenal  Leicester City      W
# 61       0          1 2022-03-16  Arsenal       Liverpool      L
# 62       1          0 2022-03-19  Arsenal     Aston Villa      W
# 63       0          0 2022-04-04  Arsenal  Crystal Palace      L
# 64       0          0 2022-04-09  Arsenal        Brighton      L

# %%
class MissingDict(dict):
    __missing__ = lambda self, key: key

map_values = {"Brighton and Hove Albion": "Brighton", "Manchester United": "Manchester Utd", "Newcastle United": "Newcastle Utd", "Tottenham Hotspur": "Tottenham", "West Ham United": "West Ham", "Wolverhampton Wanderers": "Wolves"}
mapping = MissingDict(**map_values)

# %%
combined["new_team"] = combined["team"].map(mapping)

# %%
merged = combined.merge(combined, left_on=["date", "new_team"], right_on=["date", "opponent"])

# %%
merged
# Out:
#      actual_x  predicted_x       date                   team_x     opponent_x  \
# 0           0            0 2022-01-23                  Arsenal        Burnley
# 1           1            0 2022-02-10                  Arsenal         Wolves
# 2           1            0 2022-02-19                  Arsenal      Brentford
# 3           1            1 2022-02-24                  Arsenal         Wolves
# 4           1            1 2022-03-06                  Arsenal        Watford
# ..        ...          ...        ...                      ...            ...
# 257         1            0 2022-03-13  Wolverhampton Wanderers        Everton
# 258         0            0 2022-03-18  Wolverhampton Wanderers   Leeds United
# 259         1            0 2022-04-02  Wolverhampton Wanderers    Aston Villa
# 260         0            0 2022-04-08  Wolverhampton Wanderers  Newcastle Utd
# 261         0            0 2022-04-24  Wolverhampton Wanderers        Burnley
#
# ...

# %% [markdown]
# ### Final Precision

# %%
merged[(merged["predicted_x"] == 1) & (merged["predicted_y"] ==0)]["actual_x"].value_counts()
# Out:
# actual_x
# 1    27
# 0    13
# Name: count, dtype: int64

# %%
27/40
# Out:
# 0.675
